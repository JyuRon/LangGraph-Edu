# %% [markdown]
# ### 동적 시스템 프롬프트 (Dynamic Prompting)
#
# 런타임 컨텍스트나 에이전트 상태를 기반으로 시스템 프롬프트를 동적으로 생성해야 하는 경우가 있습니다. `dynamic_prompt` 데코레이터를 사용하면 요청마다 다른 시스템 프롬프트를 적용할 수 있습니다.
#
# 이 기능은 사용자 역할, 언어 설정, 응답 형식 등을 런타임에 결정해야 할 때 유용합니다. `context_schema`를 정의하여 에이전트 호출 시 필요한 컨텍스트 정보를 전달할 수 있습니다.
#
# 아래 코드는 답변 형식과 길이를 동적으로 설정하는 에이전트를 생성합니다.

# %% [markdown]
# **ModelRequest 주요 속성:**
#
# | 속성 | 설명 |
# |:---|:---|
# | `model` | 사용할 `BaseChatModel` 인스턴스 |
# | `system_prompt` | 시스템 프롬프트 (선택적) |
# | `messages` | 대화 메시지 리스트 (시스템 프롬프트 제외) |
# | `tool_choice` | 도구 선택 설정 |
# | `tools` | 사용 가능한 도구 리스트 |
# | `response_format` | 응답 형식 지정 |
# | `state` | 현재 에이전트 상태 (`AgentState`) |
# | `runtime` | 에이전트 런타임 정보 |
# | `model_settings` | 추가 모델 설정 (dict) |
#
# 아래 코드는 `override()` 메서드를 사용하여 여러 속성을 동시에 변경하는 예시입니다.

# %%
from feature.DynamicPrompt import DynamicPromptAgent, DynamicPromptContext
from langchain_core.messages import HumanMessage

workflow = DynamicPromptAgent()

# %%
workflow.invoke(
    inputs={
        "messages": [HumanMessage(content="머신러닝의 동작 원리에 대해서 설명해줘")]
    },
    context=DynamicPromptContext(prompt_type="article", length=50),
)
# Out:
# ═══ ModelRequest ═══
#     model: "gpt-4o-mini"
#     system_prompt: None
#     context: {"prompt_type": "article", "length": 50}
#     messages:
#         index [0]
#             content: "머신러닝의 동작 원리에 대해서 설명해줘"
#             additional_kwargs: {}
#             response_metadata: {}
#             type: "human"
#             name: None
#             id: "25718672-ffa1-4fc1-9e01-ea8bbedfd5a0"
#     tool_choice: None
#     tools:
#     model_settings: {}
#
# ==================================================
# 🔄 Node: model 🔄
# - - - - - - - - - - - - - - - - - - - - - - - - -
# ================================== Ai Message ==================================
#
# 머신러닝, 데이터에서 학습하여 패턴 인식, 예측이 가능.
# ==================================================
# {'messages': [HumanMessage(content='머신러닝의 동작 원리에 대해서 설명해줘', additional_kwargs={}, response_metadata={}, id='25718672-ffa1-4fc1-9e01-ea8bbedfd5a0'),
#   AIMessage(content='머신러닝, 데이터에서 학습하여 패턴 인식, 예측이 가능.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 20, 'prompt_tokens': 62, 'total_tokens': 82, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_2ef023509e', 'id': 'chatcmpl-DhUGsV2EtZvJMwtesxSxnloR5BA09', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019e43f8-c630-79d0-87e1-9f578d4a8c05-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 62, 'output_tokens': 20, 'total_tokens': 82, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})]}

# %%
workflow.stream(
    inputs={
        "messages": [HumanMessage(content="머신러닝의 동작 원리에 대해서 설명해줘")]
    },
    context=DynamicPromptContext(prompt_type="sns", length=500),
)
# Out:
# ==================================================
# 🔄 Node: model 🔄
# - - - - - - - - - - - - - - - - - - - - - - - - -
# 🤖✨ 머신러닝의 원리! 간단히 설명해볼게요. 머신러닝은 컴퓨터가 데이터를 통해 학습하고 예측하는 기술이에요. 기본적으로는 '훈련 데이터'를 이용해 알고리즘이 패턴을 찾아내고, 이를 바탕으로 새로운 데이터를 분석하죠.
#
# 1. **데이터 수집**: 다양한 데이터를 준비해요.
# 2. **전처리**: 노이즈 제거, 정규화 등을 통해 데이터를 정리해요.
# 3. **모델 선택**: 회귀, 분류, 군집화 등 문제에 적합한 알고리즘을 선택해요.
# 4. **훈련**: 선택한 모델에 데이터셋을 넣고 학습시켜요.
# 5. **평가**: 테스트 데이터로 성능을 측정하고, 필요한 경우 하이퍼파라미터를 조정해요.
# 6. **예측**: 최종 모델로 새로운 데이터를 분석해 결과를 도출해요.
#
# 이런 과정을 통해 컴퓨터는 경험을 쌓고 더 똑똑해져요! 🚀📊 #머신러닝 #AI #기계학습
