# %%
from usecase.SimpleToolNode import SimpleToolNode, ToolNodeState


graph = SimpleToolNode()

graph.show_graph()
# Out:
# LangSmith 추적을 시작합니다.
# [프로젝트명]
# LangChain-V1-Tutorial

# %%
graph.invoke({"messages": "2025년 LangGraph 사용 사례 알려주세요."})
# Out:
# ==================================================
# 🔄 Node: chatbot 🔄
# - - - - - - - - - - - - - - - - - - - - - - - - -
# ================================== Ai Message ==================================
# Tool Calls:
#   tavily_search (call_dsT3Ggs7fm49SYmkbmtLRf6g)
#  Call ID: call_dsT3Ggs7fm49SYmkbmtLRf6g
#   Args:
#     query: 2025 LangGraph use cases
#     time_range: year
#     search_depth: advanced
# ==================================================
#
# ==================================================
# 🔄 Node: tools 🔄
# - - - - - - - - - - - - - - - - - - - - - - - - -
# ================================= Tool Message =================================
# Name: tavily_search
#
# {"query": "2025 LangGraph use cases", "follow_up_questions": null, "answer": null, "images": [], "results": [{"url": "https://sparkco.ai/blog/mastering-langgraph-state-management-in-2025", "title": "Mastering LangGraph State Management in 2025 - Sparkco AI", "content": "## Conclusion\n\nIn exploring LangGraph state management in 2025, we have uncovered significant advancements in managing complex multi-agent systems effectively. The emphasis is on explicit, reducer-driven state schemas, offering a robust foundation for scalable workflows. The precision with which LangGraph handles state transitions through TypedDicts and reducer functions ensures resilience and data integrity, even in parallel execution environments.\n\nThe use of frameworks such as LangChain, AutoGen, and LangGraph plays a critical role in simplifying intricate operations, especially with vector database integrations like Pinecone and Weaviate. For example, managing memory efficiently is crucial for maintaining context in multi-turn conversations: [...] By following these implementation steps and best practices, developers can leverage LangGraph's powerful state management capabilities to build scalable, resilient, and efficient multi-agent systems.\n\n## Case Studies\n\nLangGraph's state management system has been pivotal in transforming the way businesses handle complex workflows, enabling efficient multi-agent coordination and long-term task management. This section outlines real-world applications of LangGraph, highlighting success stories and lessons learned, as well as its impact on business outcomes and operational efficiency.\n\n### Real-World Examples of LangGraph in Action [...] As systems grow more complex, with increasing reliance on AI agents, developers face the challenge of orchestrating multi-turn conversations and maintaining long-term task contexts. LangGraph addresses these challenges by providing a framework that integrates seamlessly with popular tools and libraries like LangChain, AutoGen, and CrewAI, while also supporting vector database integrations with Pinecone, Weaviate, and Chroma.", "score": 0.8724455, "raw_content": null}, {"url": "https://www.alphabold.com/langgraph-agents-in-production/", "title": "LangGraph Agents in Production: Architecture & Costs", "content": "#### Sultan Khan\n\n#### Table of Contents\n\n## Introduction\n\nThe release of LangGraph 1.0 in October 2025 marked a watershed moment for enterprise AI and accelerated adoption of LangGraph agents in production. For the first time, organizations have access to a stable, production-grade framework for building AI agents that can persist through failures, maintain state across sessions, and incorporate human oversight at critical decision points. [...] The v1.1 release (December 2025) introduced additional middleware for production reliability, including model retry middleware with configurable exponential backoff and content moderation middleware for detecting unsafe content in agent interactions. These additions further strengthen LangGraph agents in production operating in regulated or high-risk environments\n\n### Multi-Agent Orchestration Patterns:\n\nLangGraph excels at implementing advanced Multi-agent orchestration patterns where multiple AI agents collaborate to accomplish tasks beyond individual capabilities. The framework supports diverse control flows, including single agent, multi-agent, hierarchical, and sequential patterns, all using one unified framework.\n\nCommon Multi-Agent Patterns:", "score": 0.77487355, "raw_content": null}], "response_time": 2.38, "request_id": "d30b89bd-ee0c-4f46-8b8b-b7a4351d31f8"}
# ==================================================
#
# ==================================================
# 🔄 Node: chatbot 🔄
# - - - - - - - - - - - - - - - - - - - - - - - - -
# ================================== Ai Message ==================================
#
# 2025년 LangGraph의 사용 사례에 관한 정보는 다음과 같습니다:
#
# 1. **상태 관리의 혁신**: LangGraph는 복잡한 멀티 에이전트 시스템을 효과적으로 관리하기 위한 개선된 상태 관리 기능을 제공합니다. 이를 통해 명확하고 강력한 상태 스키마를 기반으로 한 확장 가능한 워크플로우를 구축할 수 있습니다. 사용자는 TypedDicts 및 reducer 함수를 통해 상태 전환의 정확성을 보장하여 데이터 무결성을 유지할 수 있습니다.
#
# 2. **멀티 에이전트 협업**: LangGraph는 개별 능력을 넘어서는 작업을 수행하기 위해 여러 AI 에이전트가 협력할 수 있도록 지원합니다. 이 프레임워크는 단일 에이전트, 멀티 에이전트, 계층적 및 순차적 패턴과 같은 다양한 제어 흐름을 구현할 수 있습니다.
#
# 3. **리얼 월드 사례**: LangGraph의 상태 관리 시스템은 복잡한 워크플로우를 처리하는 방식을 혁신하여 효율적인 멀티 에이전트 조정 및 장기 작업 관리를 가능하게 했습니다. 기업들은 LangGraph를 통해 여러 AI 에이전트를 통합하여 생산성을 극대화하고, 운영 효율성을 향상시킬 수 있었습니다.
#
# 4. **안정적인 프로덕션 환경**: LangGraph 1.0의 출시 이후, 조직들은 안정적인 프로덕션 등급 프레임워크를 통해 AI 에이전트를 구축하고, 실패 시에도 상태를 유지하고, 중요한 결정 지점에서 인간의 감독을 통합할 수 있게 되었습니다. 향후 버전에서는 추가적인 미들웨어가 도입되어 프로덕션 신뢰성을 높였습니다.
#
# 더 자세한 내용은 다음 링크에서 확인하실 수 있습니다:
# - [Mastering LangGraph State Management in 2025 - Sparkco AI](https://sparkco.ai/blog/mastering-langgraph-state-management-in-2025)
# - [LangGraph Agents in Production: Architecture & Costs](https://www.alphabold.com/langgraph-agents-in-production/)
# ==================================================
# {'messages': [HumanMessage(content='2025년 LangGraph 사용 사례 알려주세요.', additional_kwargs={}, response_metadata={}, id='b8cd2dfc-dce0-4b76-b362-c8f6b50262bc'),
#   AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 31, 'prompt_tokens': 1220, 'total_tokens': 1251, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_026a2c69f4', 'id': 'chatcmpl-Devv20yKUqK50RQxucsANdSdpz5kN', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--019e1fb0-a990-7392-9b87-e5375585a34a-0', tool_calls=[{'name': 'tavily_search', 'args': {'query': '2025 LangGraph use cases', 'time_range': 'year', 'search_depth': 'advanced'}, 'id': 'call_dsT3Ggs7fm49SYmkbmtLRf6g', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 1220, 'output_tokens': 31, 'total_tokens': 1251, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}),
#   ToolMessage(content='{"query": "2025 LangGraph use cases", "follow_up_questions": null, "answer": null, "images": [], "results": [{"url": "https://sparkco.ai/blog/mastering-langgraph-state-management-in-2025", "title": "Mastering LangGraph State Management in 2025 - Sparkco AI", "content": "## Conclusion\\n\\nIn exploring LangGraph state management in 2025, we have uncovered significant advancements in managing complex multi-agent systems effectively. The emphasis is on explicit, reducer-driven state schemas, offering a robust foundation for scalable workflows. The precision with which LangGraph handles state transitions through TypedDicts and reducer functions ensures resilience and data integrity, even in parallel execution environments.\\n\\nThe use of frameworks such as LangChain, AutoGen, and LangGraph plays a critical role in simplifying intricate operations, especially with vector database integrations like Pinecone and Weaviate. For example, managing memory efficiently is crucial for maintaining context in multi-turn conversations: [...] By following these implementation steps and best practices, developers can leverage LangGraph\'s powerful state management capabilities to build scalable, resilient, and efficient multi-agent systems.\\n\\n## Case Studies\\n\\nLangGraph\'s state management system has been pivotal in transforming the way businesses handle complex workflows, enabling efficient multi-agent coordination and long-term task management. This section outlines real-world applications of LangGraph, highlighting success stories and lessons learned, as well as its impact on business outcomes and operational efficiency.\\n\\n### Real-World Examples of LangGraph in Action [...] As systems grow more complex, with increasing reliance on AI agents, developers face the challenge of orchestrating multi-turn conversations and maintaining long-term task contexts. LangGraph addresses these challenges by providing a framework that integrates seamlessly with popular tools and libraries like LangChain, AutoGen, and CrewAI, while also supporting vector database integrations with Pinecone, Weaviate, and Chroma.", "score": 0.8724455, "raw_content": null}, {"url": "https://www.alphabold.com/langgraph-agents-in-production/", "title": "LangGraph Agents in Production: Architecture & Costs", "content": "#### Sultan Khan\\n\\n#### Table of Contents\\n\\n## Introduction\\n\\nThe release of LangGraph 1.0 in October 2025 marked a watershed moment for enterprise AI and accelerated adoption of LangGraph agents in production. For the first time, organizations have access to a stable, production-grade framework for building AI agents that can persist through failures, maintain state across sessions, and incorporate human oversight at critical decision points. [...] The v1.1 release (December 2025) introduced additional middleware for production reliability, including model retry middleware with configurable exponential backoff and content moderation middleware for detecting unsafe content in agent interactions. These additions further strengthen LangGraph agents in production operating in regulated or high-risk environments\\n\\n### Multi-Agent Orchestration Patterns:\\n\\nLangGraph excels at implementing advanced Multi-agent orchestration patterns where multiple AI agents collaborate to accomplish tasks beyond individual capabilities. The framework supports diverse control flows, including single agent, multi-agent, hierarchical, and sequential patterns, all using one unified framework.\\n\\nCommon Multi-Agent Patterns:", "score": 0.77487355, "raw_content": null}], "response_time": 2.38, "request_id": "d30b89bd-ee0c-4f46-8b8b-b7a4351d31f8"}', name='tavily_search', id='ff41bd28-01dd-4961-862a-53782de091fb', tool_call_id='call_dsT3Ggs7fm49SYmkbmtLRf6g'),
#   AIMessage(content='2025년 LangGraph의 사용 사례에 관한 정보는 다음과 같습니다:\n\n1. **상태 관리의 혁신**: LangGraph는 복잡한 멀티 에이전트 시스템을 효과적으로 관리하기 위한 개선된 상태 관리 기능을 제공합니다. 이를 통해 명확하고 강력한 상태 스키마를 기반으로 한 확장 가능한 워크플로우를 구축할 수 있습니다. 사용자는 TypedDicts 및 reducer 함수를 통해 상태 전환의 정확성을 보장하여 데이터 무결성을 유지할 수 있습니다.\n\n2. **멀티 에이전트 협업**: LangGraph는 개별 능력을 넘어서는 작업을 수행하기 위해 여러 AI 에이전트가 협력할 수 있도록 지원합니다. 이 프레임워크는 단일 에이전트, 멀티 에이전트, 계층적 및 순차적 패턴과 같은 다양한 제어 흐름을 구현할 수 있습니다.\n\n3. **리얼 월드 사례**: LangGraph의 상태 관리 시스템은 복잡한 워크플로우를 처리하는 방식을 혁신하여 효율적인 멀티 에이전트 조정 및 장기 작업 관리를 가능하게 했습니다. 기업들은 LangGraph를 통해 여러 AI 에이전트를 통합하여 생산성을 극대화하고, 운영 효율성을 향상시킬 수 있었습니다.\n\n4. **안정적인 프로덕션 환경**: LangGraph 1.0의 출시 이후, 조직들은 안정적인 프로덕션 등급 프레임워크를 통해 AI 에이전트를 구축하고, 실패 시에도 상태를 유지하고, 중요한 결정 지점에서 인간의 감독을 통합할 수 있게 되었습니다. 향후 버전에서는 추가적인 미들웨어가 도입되어 프로덕션 신뢰성을 높였습니다.\n\n더 자세한 내용은 다음 링크에서 확인하실 수 있습니다:\n- [Mastering LangGraph State Management in 2025 - Sparkco AI](https://sparkco.ai/blog/mastering-langgraph-state-management-in-2025)\n- [LangGraph Agents in Production: Architecture & Costs](https://www.alphabold.com/langgraph-agents-in-production/)', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 457, 'prompt_tokens': 1971, 'total_tokens': 2428, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 1152}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_026a2c69f4', 'id': 'chatcmpl-Devv84sOSnXM2h71HG6YoOSNRZEMR', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019e1fb0-bde2-72f1-b6bb-8173e44ffd7e-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 1971, 'output_tokens': 457, 'total_tokens': 2428, 'input_token_details': {'audio': 0, 'cache_read': 1152}, 'output_token_details': {'audio': 0, 'reasoning': 0}})]}

# %%
graph.stream({"messages": "2025년 LangGraph 사용 사례 알려주세요."})
# Out:
# ==================================================
# 🔄 Node: chatbot 🔄
# - - - - - - - - - - - - - - - - - - - - - - - - -
#
# ==================================================
# 🔄 Node: tools 🔄
# - - - - - - - - - - - - - - - - - - - - - - - - -
# {"query": "2025 LangGraph use cases", "follow_up_questions": null, "answer": null, "images": [], "results": [{"url": "https://sparkco.ai/blog/mastering-langgraph-state-management-in-2025", "title": "Mastering LangGraph State Management in 2025 - Sparkco AI", "content": "## Conclusion\n\nIn exploring LangGraph state management in 2025, we have uncovered significant advancements in managing complex multi-agent systems effectively. The emphasis is on explicit, reducer-driven state schemas, offering a robust foundation for scalable workflows. The precision with which LangGraph handles state transitions through TypedDicts and reducer functions ensures resilience and data integrity, even in parallel execution environments.\n\nThe use of frameworks such as LangChain, AutoGen, and LangGraph plays a critical role in simplifying intricate operations, especially with vector database integrations like Pinecone and Weaviate. For example, managing memory efficiently is crucial for maintaining context in multi-turn conversations: [...] By following these implementation steps and best practices, developers can leverage LangGraph's powerful state management capabilities to build scalable, resilient, and efficient multi-agent systems.\n\n## Case Studies\n\nLangGraph's state management system has been pivotal in transforming the way businesses handle complex workflows, enabling efficient multi-agent coordination and long-term task management. This section outlines real-world applications of LangGraph, highlighting success stories and lessons learned, as well as its impact on business outcomes and operational efficiency.\n\n### Real-World Examples of LangGraph in Action [...] As systems grow more complex, with increasing reliance on AI agents, developers face the challenge of orchestrating multi-turn conversations and maintaining long-term task contexts. LangGraph addresses these challenges by providing a framework that integrates seamlessly with popular tools and libraries like LangChain, AutoGen, and CrewAI, while also supporting vector database integrations with Pinecone, Weaviate, and Chroma.", "score": 0.8724455, "raw_content": null}, {"url": "https://www.alphabold.com/langgraph-agents-in-production/", "title": "LangGraph Agents in Production: Architecture & Costs", "content": "#### Sultan Khan\n\n#### Table of Contents\n\n## Introduction\n\nThe release of LangGraph 1.0 in October 2025 marked a watershed moment for enterprise AI and accelerated adoption of LangGraph agents in production. For the first time, organizations have access to a stable, production-grade framework for building AI agents that can persist through failures, maintain state across sessions, and incorporate human oversight at critical decision points. [...] The v1.1 release (December 2025) introduced additional middleware for production reliability, including model retry middleware with configurable exponential backoff and content moderation middleware for detecting unsafe content in agent interactions. These additions further strengthen LangGraph agents in production operating in regulated or high-risk environments\n\n### Multi-Agent Orchestration Patterns:\n\nLangGraph excels at implementing advanced Multi-agent orchestration patterns where multiple AI agents collaborate to accomplish tasks beyond individual capabilities. The framework supports diverse control flows, including single agent, multi-agent, hierarchical, and sequential patterns, all using one unified framework.\n\nCommon Multi-Agent Patterns:", "score": 0.77487355, "raw_content": null}], "response_time": 0.0, "request_id": "63163ecb-2065-4093-856c-53538e51cdfe"}
# ==================================================
# 🔄 Node: chatbot 🔄
# - - - - - - - - - - - - - - - - - - - - - - - - -
# 2025년 LangGraph의 사용 사례에 대한 정보가 다음과 같이 두 가지 주된 출처에서 확인되었습니다.
#
# 1. **[Mastering LangGraph State Management in 2025](https://sparkco.ai/blog/mastering-langgraph-state-management-in-2025)**:
#    - LangGraph의 상태 관리 시스템은 복잡한 멀티 에이전트 시스템을 효과적으로 관리하는 데 중요한 역할을 합니다. 개발자들은 TypedDict 및 리듀서 기능을 통해 상태 전이를 정확하게 처리함으로써 데이터 무결성을 유지할 수 있습니다.
#    - LangGraph의 여러 프레임워크와의 통합(예: LangChain, AutoGen, CrewAI)은 비즈니스 프로세스를 간소화하고 멀티 턴 대화에서의 메모리 관리를 효율적으로 지원합니다.
#
# 2. **[LangGraph Agents in Production: Architecture & Costs](https://www.alphabold.com/langgraph-agents-in-production/)**:
#    - 2025년 10월에 출시된 LangGraph 1.0은 생산 환경에서 AI 에이전트를 구축하는 데 있어 중요한 이정표가 되었습니다. 이 프레임워크는 장애를 견디고, 세션 간 상태를 유지하며, 중요한 결정 포인트에서 인간의 감독을 통합할 수 있는 안정적인 구조를 제공합니다.
#    - LangGraph는 여러 AI 에이전트가 협력하여 개별 능력을 초월하는 작업을 수행하는 진보된 멀티 에이전트 오케스트레이션 패턴을 지원합니다.
#
# 이 정보는 LangGraph가 비즈니스의 복잡한 워크플로를 어떻게 변화시키고 있는지, 그리고 멀티 에이전트 시스템에서의 실용적인 응용을 보여줍니다.
